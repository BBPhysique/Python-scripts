# %%
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams.update({'font.size': 18})

def f(pKa):
    plt.figure(figsize=(10,5))
    #définition de l'intervalle de points de calcul
    x = np.linspace(0, 14, num=1000)
    
    #calcul et tracé de la proportion en base
    plt.plot(x, 100*(10**(x-pKa))/(1+10**(x-pKa)),color = 'red',label = "base") 
    #calcul et tracé de la proportion en acide
    plt.plot(x, 100/(1+10**(x-pKa)),color = 'blue', label = 'acide') 
    
    #mise en forme du graphique
    plt.ylim(-0.05*100, 1.05*100)
    plt.ylabel("Proportion (%)")
    plt.xlabel("pH")
    
    
    plt.axvline(x=pKa, linestyle='dashed', color='black',label = 'pKa')
    
    plt.legend()
    plt.show()
             
#actualisation de la barre d'actualisation dynamique
interactive_plot = interactive(f, pKa=(2, 12,0.3333))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=6.999499999999999, description='pKa', max=12.0, min=2.0, step=0.3333),…

# %%
plt.rcParams.update({'font.size': 18})

def fampho(pKa1,pKa2):
    plt.figure(figsize=(10,5))
    #définition de l'intervalle de points de calcul
    x = np.linspace(0, 14, num=1000)
    
    #calcul et tracé de la proportion en acide
    prop_acide = 100/(1+10**(x-pKa1)+10**(2*x-pKa1-pKa2))
    plt.plot(x, prop_acide,color = 'red',label = "acide") 
    #calcul et tracé de la proportion en amphotère
    plt.plot(x, prop_acide*10**(x-pKa1),color = 'green',label = "amphotère") 
    #calcul et tracé de la proportion en base
    plt.plot(x, prop_acide*10**(2*x-pKa1-pKa2),color = 'blue', label = 'base') 
    
    plt.axvline(x=pKa1, linestyle='dashed', color='yellow',label = 'pKa1')
    plt.axvline(x=pKa2, linestyle='dashed', color='cyan',label = 'pKa2')
    
    #mise en forme du graphique
    plt.ylim(-0.05*100, 1.05*100)
    plt.ylabel("Proportion (%)")
    plt.xlabel("pH")
    plt.legend()
    plt.show()
        
print("Proportion d'une espèce (%) en fonction du pH")
#actualisation de la barre d'actualisation dynamique
interactive_plot = interactive(fampho, pKa1=(2, 12,0.3333),pKa2=(2, 12,0.3333))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# Proportion d'une espèce (%) en fonction du pH
# interactive(children=(FloatSlider(value=6.999499999999999, description='pKa1', max=12.0, min=2.0, step=0.3333)…

# %%
f(6.33)

# %%
fampho(6.33,10.33)
